# %% [markdown]
# <a href="https://colab.research.google.com/github/CzhD-arch/comsci_project1_Group3/blob/main/comsci_project1_Group3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calculator_result(num1, num2):
  return total

#To define looping
keep_going = 'yes'
while keep_going == 'yes':

 num1 = int(input("Enter the first number:")) #Ask for both numbers
 num2 = int(input("Enter the second number:"))
 operation = input("Enter the opertion you want to perform (+, -, /, *): ") #Ask for the operations they would like to perform

#Vary operation from operator
 if operation == '+':
   total = num1 + num2
 elif operation == '-':
   total = num1 - num2
 elif operation == '/':
   total = num1 / num2
 elif operation == '*':
   total = num1 * num2
 else:
   print("Invalid operation")

#Send total from calculator
 print(f"Your total is, {total}.")

#Ask if they want to continue
 keep_going = input("Do you want to continue?: (yes/no)") #Ask if they would like to continue the process

print("Thank you for using our calculator!")
# Out:
# Enter the first number:5
# Enter the second number:5
# Enter the opertion you want to perform (+, -, /, *): *
# Your total is, 25.
# Do you want to continue?: (yes/no)no
# Thank you for using our calculator!
