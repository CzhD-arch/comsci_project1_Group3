# %% [markdown]
# <a href="https://colab.research.google.com/github/CzhD-arch/comsci_project1_Group3/blob/main/comsci_project1_Group3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calculator_result(num1, num2):
  return total

keep_going = 'yes'
while keep_going == 'yes':

 num1 = int(input("Enter the first number:"))
 num2 = int(input("Enter the second number:"))
 operation = input("Enter the opertion you want to perform (+, -, /, *): ")

 if operation == '+':
   total = num1 + num2
 elif operation == '-':
   total = num1 - num2
 elif operation == '/':
   total = num1 / num2
 elif operation == '*':
   total = num1 * num2
 else:
   print("Invalid operation")

 print(f"Your total is, {total}.")

 keep_going = input("Do you want to continue?: (yes/no)")

print("Greetings!")
# Out:
# Enter the first number:5
# Enter the second number:5
# Enter the opertion you want to perform (+, -, /, *): -
# Your total is, 0.
# Do you want to continue?: (yes/no)yes
